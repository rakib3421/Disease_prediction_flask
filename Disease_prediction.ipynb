# %%
import pandas as pd

# Read in the dataset
data = pd.read_csv("dataset.csv")
data
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
data.columns
# Out:
# Index(['Disease', 'Symptom_1', 'Symptom_2', 'Symptom_3', 'Symptom_4',
#        'Symptom_5', 'Symptom_6', 'Symptom_7', 'Symptom_8', 'Symptom_9',
#        'Symptom_10', 'Symptom_11', 'Symptom_12', 'Symptom_13', 'Symptom_14',
#        'Symptom_15', 'Symptom_16', 'Symptom_17'],
#       dtype='object')

# %%
data = data.drop(['Symptom_7', 'Symptom_8', 'Symptom_9',
       'Symptom_10', 'Symptom_11', 'Symptom_12', 'Symptom_13', 'Symptom_14',
       'Symptom_15', 'Symptom_16', 'Symptom_17'],axis=1)

# %%
data
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
# Perform data cleaning and preprocessing
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# Disease      0
# Symptom_1    0
# Symptom_2    0
# Symptom_3    0
# Symptom_4    0
# Symptom_5    0
# Symptom_6    0
# dtype: int64

# %%
data = data.reset_index(0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2934 entries, 0 to 2933
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      2934 non-null   int64
#  1   Disease    2934 non-null   object
#  2   Symptom_1  2934 non-null   object
#  3   Symptom_2  2934 non-null   object
#  4   Symptom_3  2934 non-null   object
#  5   Symptom_4  2934 non-null   object
#  6   Symptom_5  2934 non-null   object
#  7   Symptom_6  2934 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 183.5+ KB

# %%
data['Disease'].value_counts()
# Out:
# hepatitis A                                120
# Hepatitis B                                120
# Hypothyroidism                             120
# Varicose veins                             120
# Pneumonia                                  120
# Common Cold                                120
# Tuberculosis                               120
# Alcoholic hepatitis                        120
# Hepatitis E                                120
# Hepatitis D                                120
# Chronic cholestasis                        120
# Hyperthyroidism                            120
# Hypoglycemia                               120
# Typhoid                                    120
# Dengue                                     120
# Chicken pox                                120
# Malaria                                    120
# Jaundice                                   120
# Migraine                                   120
# Diabetes                                   120
# ...

# %%
data
# Out:
#       index                                  Disease      Symptom_1  \
# 0        20                                     GERD   stomach_pain
# 1        30                      Chronic cholestasis        itching
# 2        31                      Chronic cholestasis       vomiting
# 3        32                      Chronic cholestasis        itching
# 4        33                      Chronic cholestasis        itching
# ...     ...                                      ...            ...
# 2929   4911                          Hyperthyroidism        fatigue
# 2930   4912                             Hypoglycemia       vomiting
# 2931   4913                          Osteoarthristis     joint_pain
# 2932   4915  (vertigo) Paroymsal  Positional Vertigo       vomiting
# 2933   4918                                Psoriasis      skin_rash
#
#             Symptom_2          Symptom_3             Symptom_4  \
# 0             acidity   ulcers_on_tongue              vomiting
# ...

# %%
data.columns
# Out:
# Index(['index', 'Disease', 'Symptom_1', 'Symptom_2', 'Symptom_3', 'Symptom_4',
#        'Symptom_5', 'Symptom_6'],
#       dtype='object')

# %%
data = data.drop(['index'],axis=1)
data.to_csv('cleaned_data.csv',index=False)

# %%
x = data.drop(['Disease'],axis=1)
y = data['Disease']

# %%
x
# Out:
#           Symptom_1        Symptom_2          Symptom_3             Symptom_4  \
# 0      stomach_pain          acidity   ulcers_on_tongue              vomiting
# 1           itching         vomiting     yellowish_skin                nausea
# 2          vomiting   yellowish_skin             nausea      loss_of_appetite
# 3           itching   yellowish_skin             nausea      loss_of_appetite
# 4           itching         vomiting             nausea      loss_of_appetite
# ...             ...              ...                ...                   ...
# 2929        fatigue      mood_swings        weight_loss          restlessness
# 2930       vomiting          fatigue            anxiety              sweating
# 2931     joint_pain        neck_pain          knee_pain        hip_joint_pain
# 2932       vomiting         headache             nausea    spinning_movements
# 2933      skin_rash       joint_pain       skin_peeling   silver_like_dusting
#
# ...

# %%
y
# Out:
# 0                                          GERD
# 1                           Chronic cholestasis
# 2                           Chronic cholestasis
# 3                           Chronic cholestasis
# 4                           Chronic cholestasis
#                          ...
# 2929                            Hyperthyroidism
# 2930                               Hypoglycemia
# 2931                            Osteoarthristis
# 2932    (vertigo) Paroymsal  Positional Vertigo
# 2933                                  Psoriasis
# Name: Disease, Length: 2934, dtype: object

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
# Out:
# OneHotEncoder()

# %%
ohe = OneHotEncoder()
ohe.fit(x[['Symptom_1', 'Symptom_2', 'Symptom_3', 'Symptom_4', 'Symptom_5', 'Symptom_6']])

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Select a suitable machine learning model
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
pipe = make_pipeline(columns_trans,model)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array([' acidity', ' chills', ' continuous_sneezing', ' cramps',
#        ' fatigue', ' indigestion', ' joint_pain', ' mood_swings',
#        ' skin_rash', ' stomach_pain', ' vomiting', ' weight_gain',
#        ' weight_loss', ' yellowish_skin', 'itching'], dtype=object...
#        ' prominent_veins_on_calf', ' puffy_face_and_eyes', ' stiff_neck',
#        ' sweating', ' swelled_lymph_nodes', ' swollen_blood_vessels',
#        ' unsteadiness', ' yellowing_of_eyes', ' yellowish_skin'],
#       dtype=object)],
#                                                                 handle_unknown='ignore'),
#                                                   ['Symptom_1', 'Symptom_2',
# ...

# %%
pipe.score(X_test,y_test)
# Out:
# 0.9931856899488927

# %%
y_pred = pipe.predict(X_test)

# %%
X_test.iloc[0]
# Out:
# Symptom_1          joint_pain
# Symptom_2           neck_pain
# Symptom_3           knee_pain
# Symptom_4      hip_joint_pain
# Symptom_5     swelling_joints
# Symptom_6     painful_walking
# Name: 2418, dtype: object

# %%
y_test
# Out:
# 2418                            Osteoarthristis
# 2608    (vertigo) Paroymsal  Positional Vertigo
# 2922                                Hepatitis E
# 685                                    Migraine
# 1041                                  Pneumonia
#                          ...
# 456                                   Diabetes
# 462                            Bronchial Asthma
# 2928                             Hypothyroidism
# 1536                                   Jaundice
# 381                                   Pneumonia
# Name: Disease, Length: 587, dtype: object

# %%
from sklearn.metrics import accuracy_score
print("The accuracy Score of the model:",round(accuracy_score(y_pred,y_test))*100)
# Out:
# The accuracy Score of the model: 100

# %%
X_test
# Out:
#         Symptom_1     Symptom_2                      Symptom_3  \
# 2418   joint_pain     neck_pain                      knee_pain
# 2608     vomiting      headache                         nausea
# 2922   joint_pain      vomiting                        fatigue
# 685       acidity   indigestion   blurred_and_distorted_vision
# 1041       chills       fatigue                          cough
# ...           ...           ...                            ...
# 456       fatigue   weight_loss                   restlessness
# 462       fatigue         cough                     high_fever
# 2928      fatigue   weight_gain           cold_hands_and_feets
# 1536      itching      vomiting                        fatigue
# 381        chills         cough                     high_fever
#
#                    Symptom_4                      Symptom_5         Symptom_6
# 2418          hip_joint_pain                swelling_joints   painful_walking
# ...

# %%
import numpy as np

# %%
prediction = pipe.predict(pd.DataFrame(columns=x.columns,data=np.array([x.iloc[0]]).reshape(1,6)))
print(prediction[0])
# Out:
# GERD

# %%
import pickle
with open('Disease_prediction.pickle', 'wb') as file:
    pickle.dump(pipe, file)
